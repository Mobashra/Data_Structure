# %%
#Task : 1


#subTask :1
class Node:
    
    def __init__(self,element,next):
        self.element = element
        self.next = next
        
#subTask : 2        
class MyList:
    
    def __init__(self,array=None):
        
        # Empty list
        if array is None:
            self.head = None
            
        # list from array   
        elif isinstance(array,list):
            self.head = None
            tail = None
            
            for i in array:
                NewNode = Node(i,None)
                
                if self.head is None:
                    self.head = NewNode
                    tail = NewNode
                else:
                    tail.next = NewNode
                    tail = NewNode
                    
        # list from another list   
        elif isinstance(array,object):
            self.head = None
            NewTail = None
            NextNode = array.head
            
            while Nextnode is not None:
                NewNode = Node(NextNode.element)
                
                if self.head is None:
                    self.head = NextNode
                    NewTail = NextNode
                else:
                    NewTail.next = NextNode
                    NewTail = Nextnode
                    
                NextNode = NextNode.next
                
    #shows the list as output          
    def showList(self):
        if self.head is None:
            print("Empty list")
        else:
            tail = self.head
            while tail is not None:
                print(str(tail.element)+",",end=" ")
                tail = tail.next
                
    # returns Boolean value to show if list is empty or not       
    def isEmpty(self):
        if self.head is None:
            return True
        else:
            return False
            
    # removes the elements of an exisitng list       
    def clear(self):
        tail = self.head
        while tail is not None:
            tail.element = None
            tail = tail.next
                   
    #insert new element at end 
    def insert(self,newElement):
        node = Node(newElement,None)
        
        tail = self.head
        while tail is not None:
            if node.element == tail.element:
                print("Key already exists")
                return self.head
            tail = tail.next

        tail2 = self.head
        while tail2 is not None:
            PreTail = tail2
            tail2 = tail2.next
            
        PreTail.next = node
    
   
        
        
        
        
    # looking for even numbers in the given list 
    def isEvenPresent(self):
        node = self.head
        head = None
        tail = None
        l = MyList()

        while node is not None:
            if node.element % 2 == 0:
                head = Node(node.element,None)

                if head is None:
                    head = NewNode
                    tail = NewNode
                else:
                    tail.next = NewNode
                    tail = NewNode

            node = node.next

        l.head = head   
        return l
    
    #looking for is an element present in given list and return boolean value
    def isElementPresent(self,elem):
        node = self.head
        checker = False

        while node is not None:
            if node.element == elem:
                checker = True
            else:
                return checker

            node = node.next
        return isElementPresent

    def reversingList(self):
        node = self.head
        head = None
        
        while node is not None:
            temp = node.next
            node.next = head
            head = node
            node = temp

        self.head = head

        return reversingList

    # 
    
    def sort(self):
        temp = self.head
        while temp != None:
            nextTemp = temp.next
            while nextTemp != None:
                if temp.element > nextTemp.element:
                    store = temp.element
                    temp.element = nextTemp.element
                    nextTemp.element = store
                nextTemp = nextTemp.next
            temp = temp.next
        self.showList()
array = [10,90,30,60,50]
list1 = MyList(array)

l2 = MyList(array)
print(l2.sort)
# Out:
# <bound method MyList.sort of <__main__.MyList object at 0x0000022FBAC5EB88>>
